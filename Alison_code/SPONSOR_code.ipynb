# %%
import pandas as pd
import numpy as np
# %cd drive/My\ Drive/HRL/Data\ Cleaning
# Out:
# /content/drive/My Drive/HRL/Data Cleaning

# %% [markdown]
# # Prelimanary Ops

# %%
data = pd.read_excel('NY_data.xlsx')
data.head()
# Out:
#   DONE Y/N NO FORM 431        DATE  Unnamed: 3  Screened  BOX  CASENO1  \
# 0      NaN         NaN         NaN         NaN       0.0  1.0      5.0
# 1      NaN           X  2020.03.18         1.0       0.0  1.0      5.0
# 2      NaN         NaN         NaN         NaN       0.0  1.0      5.0
# 3      NaN         NaN         NaN         NaN       0.0  1.0      5.0
# 4      NaN         NaN         NaN         NaN       0.0  1.0      5.0
#
#    CASENO2    NAME1 NAME2 NAME3 ALIAS1 ALIAS2 ALIAS3 CHINESE1 CHINESE2  \
# 0      3.0     CHIN   GOK    PO   CHIN   KUNG   PACK      NaN      NaN
# 1      4.0      HOM  CHEE   NaN   DONG     AH   CHEE      NaN      NaN
# 2      9.0  WILLIAM     K  WONG   WONG   KING   SING      NaN      NaN
# 3     10.0      LEE   DEN   NaN    NaN    NaN    NaN      NaN      NaN
# 4     19.0      YEE  HING   NaN     YU    YUK    YIN      NaN      NaN
#
#    CHINESE3  CHINESE4 SEX           PORT     BIRTHPLACE HOMETOWN OCUPATION1  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data["SPONSOR"].value_counts()
# Out:
# COLUMBIA UNIVERSITY                                   31
# SANG CHONG & CO,NYC                                   19
# SUN KWONG ON                                          18
# CANTON RESTAURANT                                     18
# SOY KEE CO                                            15
# QUONG YEE WO                                          15
# KUAN TANG LUNG & CO,NYC                               15
# QUONG YUEN SHING                                      14
# WING WO CHONG & CO,NYC                                13
# YMCA                                                  13
# YING CHONG CO                                         13
# SUN KWONG ON CO                                       12
# ORIENTAL RESTAURANT                                   12
# WING ON TAI & CO,PA                                   11
# WING WO CHONG                                         11
# WING ON WO                                            11
# ...

# %% [markdown]
# # Separate Geo Markers

# %%
sponsor_column = data.loc[:, 'SPONSOR']
print(type(sponsor_column))
print(len(sponsor_column))
sponsor_column
# Out:
# <class 'pandas.core.series.Series'>
# 18563
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# ...

# %%
zeros = 0
ones = 0
twos = 0
overthrees = 0
for line in sponsor_column:
    if type(line) != float:
        count = line.count(',')
        if count == 0:
            zeros += 1
        elif count == 1:
            ones += 1
        elif count == 2:
            twos += 1
        else:
            overthrees += 1

print(zeros, ones, twos, overthrees)
# Out:
# 2168 1207 41 2

# %%
sponsor_name = []
geo_markers = []
blank = sponsor_column[0]
i = 0
for line in sponsor_column:
    i += 1
    # not nan
    if type(line) != float:
        count = line.count(',')
        if count == 1:
            if ', ' in line:
                line_list = line.split(', ')
            elif ',' in line:
                line_list = line.split(',')
            else:
                print('this is wrong')
            sponsor_name.append(line_list[0])
            geo_markers.append(line_list[1])
        elif count >= 2:
            print('manual labor:', i)
            sponsor_name.append(line)
            geo_markers.append(blank)
        else:
            sponsor_name.append(line)
            geo_markers.append(blank)
        
    # is nan
    else:
        sponsor_name.append(line)
        geo_markers.append(line)
# Out:
# manual labor: 53
# manual labor: 205
# manual labor: 1001
# manual labor: 1597
# manual labor: 1650
# manual labor: 1749
# manual labor: 1757
# manual labor: 1911
# manual labor: 1954
# manual labor: 2379
# manual labor: 2390
# manual labor: 2402
# manual labor: 2413
# manual labor: 2427
# manual labor: 2537
# manual labor: 2565
# manual labor: 2566
# manual labor: 2617
# manual labor: 3509
# manual labor: 4702
# manual labor: 9707
# manual labor: 9888
# manual labor: 10155
# manual labor: 10587
# manual labor: 10770
# manual labor: 10784
# manual labor: 10963
# manual labor: 11548
# manual labor: 11767
# manual labor: 11811
# manual labor: 11909
# manual labor: 11916
# manual labor: 12608
# manual labor: 12631
# manual labor: 13448
# manual labor: 13472
# manual labor: 13549
# manual labor: 14297
# manual labor: 14299
# manual labor: 14420
# manual labor: 14436
# manual labor: 15019
# manual labor: 18481

# %% [markdown]
# then I cleaned up manually, which is much easier given that we only have ~50

# %% [markdown]
# # Sep sponsor names

# %%
data = pd.read_csv('./cleaned_data/SPONSOR_SEP.csv')
data.head()
# Out:
#   SPONSOR_NAME geo_marker SPONSOR_NAME1 SPONSOR_NAME2 SPONSOR_NAME3
# 0          NaN        NaN           NaN           NaN           NaN
# 1          NaN        NaN           NaN           NaN           NaN
# 2          NaN        NaN           NaN           NaN           NaN
# 3          NaN        NaN           NaN           NaN           NaN
# 4          NaN        NaN           NaN           NaN           NaN

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data["SPONSOR_NAME"].value_counts()
# Out:
# COLUMBIA UNIVERSITY                                   43
# CANTON RESTAURANT                                     20
# SUN KWONG ON                                          19
# SANG CHONG & CO                                       19
# KUAN TANG LUNG & CO                                   17
# WING WO CHONG & CO                                    16
# ORIENTAL RESTAURANT                                   16
# QUONG YEE WO                                          15
# SOY KEE CO                                            15
# QUONG YUEN SHING                                      14
# SUN KWONG ON CO                                       13
# YMCA                                                  13
# YING CHONG CO                                         13
# KWONG TAI CHONG & CO                                  12
# WING WO CHONG                                         12
# TAI LUNG CO                                           12
# ...

# %%
i = 1
for line in data["SPONSOR_NAME"]:
    i += 1
    if type(line) != float:
        count = line.count(',') + line.count('/') + line.count(';')
        if count >= 1:
            print('line', i)
# Out:
# line 291
# line 326
# line 332
# line 843
# line 863
# line 911
# line 1241
# line 1849
# line 2235
# line 2340
# line 2414
# line 2428
# line 2490
# line 2538
# line 2556
# line 2618
# line 3510
# line 9705
# line 9708
# line 9709
# line 9719
# line 9729
# line 9732
# line 9805
# line 9808
# line 9824
# line 9835
# line 9857
# line 9865
# line 9880
# line 9889
# line 9898
# line 9957
# line 9993
# line 10030
# line 10046
# line 10100
# line 10142
# line 10168
# line 10183
# line 10215
# line 10296
# line 10300
# line 10316
# line 10333
# line 10334
# line 10394
# line 10395
# line 10396
# line 10410
# line 10461
# line 10476
# line 10478
# line 10484
# line 10495
# line 10511
# line 10516
# line 10518
# line 10551
# line 10588
# line 10612
# line 10632
# line 10643
# line 10672
# line 10686
# line 10696
# line 10713
# line 10714
# line 10727
# line 10729
# line 10735
# line 10749
# line 10755
# line 10762
# line 10765
# line 10766
# line 10771
# line 10784
# line 10790
# line 10798
# ...

# %% [markdown]
# # Spelling Check

# %%
data["geo_marker"].value_counts()
# Out:
# NYC               555
# PA                123
# NY                120
# NJ                 58
# MD                 45
# MA                 29
# WASHINGTON DC      16
# CT                 10
# VA                 10
# BROOKLYN, NY        5
# CANADA              4
# OHIO                4
# SAN FRANCISCO       3
# OH                  3
# WASHINGTON, DC      3
# BROOKLYN,NY         2
# HONG KONG           2
# RI                  2
# IL                  2
# KENTUCKY            2
# IA                  2
# ILLINOIS            1
# WA                  1
# SC                  1
# CA                  1
# WY                  1
# WASHINTON, DC       1
# SOUTH DAKOTA        1
# PENN STATE          1
# LAUNDRY             1
# ANN ARBOR           1
# IOWA                1
# NEWARK, NJ          1
# VI                  1
# NEW HAVEN,CT        1
# INDIANA             1
# SAN JOSE, CA        1
# HARTFORD, CT        1
# NEW YORK CITY       1
# GA                  1
# WASHINGTON          1
# ...

# %%
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['WASH. DC', 'WASHINGTON DC', 'WASHINGTON, DC', 'WASHINTON, DC', 'WASHINGTON'], "WASHINGTON, D.C.")
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['OHIO'], "OH")
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['NEW HAVEN,CT'], "NEW HAVEN, CT")
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['BROOKLYN', 'BROOKLYN,NY'], "BROOKLYN, NY")
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['SOUTH DAKOTA'], "SD")
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['IOWA'], "IA")
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['KENTUCKY'], "KY")
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['ILLINOIS'], "IL")
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['NEW YORK CITY'], "NYC")
data.loc[:, "geo_marker"] = data.loc[:, "geo_marker"].replace(['INDIANA'], "IN")

# %%
data["SPONSOR_NAME3"].value_counts()
# Out:
# COLUMBIA UNIVERSITY       3
# ADOLF GOBEL CO            1
# SUNRISE RESTAURANT        1
# SUN KWONG ON CO           1
# New York University       1
# WING ON TANK CO           1
# COLUMBIA UNIVERISTY       1
# AMER LOCOMOTIVE CO        1
# SANG SANG CO              1
# LOUIE LEE LAUNDRY         1
# UNIVERSITY OF MICHIGAN    1
# KWONG CHEUNG CO           1
# PARADISE RESTAURANT       1
# LIBERTY RESTAURANT        1
# JOYLAND RESTAURANT        1
# GREAT EAST                1
# TEXAS OIL                 1
# NAM KIM RESTAURANT        1
# PRINCETON UNIVERSITY      1
# YEE WO LUNG CO            1
# WING YING LUNG CO         1
# Name: SPONSOR_NAME3, dtype: int64

# %%
data.loc[:, "SPONSOR_NAME3"] = data.loc[:, "SPONSOR_NAME3"].replace(['COLUMBIA', 'COLUMBIA UNIV', "COLUMBIA UNIVERISTY"], "COLUMBIA UNIVERSITY")
data.loc[:, "SPONSOR_NAME3"] = data.loc[:, "SPONSOR_NAME3"].replace(['TAI TUNG REST.'], "COLUMBIA UNIVERISTY")
data.loc[:, "SPONSOR_NAME3"] = data.loc[:, "SPONSOR_NAME3"].replace(['NYU'], "New York University")
data.loc[:, "SPONSOR_NAME3"] = data.loc[:, "SPONSOR_NAME3"].replace(['MICHIGAN'], "UNIVERSITY OF MICHIGAN")
data.loc[:, "SPONSOR_NAME3"] = data.loc[:, "SPONSOR_NAME3"].replace(['PRINCETON UNIV.'], "PRINCETON UNIVERSITY")
data.loc[:, "SPONSOR_NAME3"] = data.loc[:, "SPONSOR_NAME3"].replace(['NAM KIM REST.'], "NAM KIM RESTAURANT")
data.loc[:, "SPONSOR_NAME3"] = data.loc[:, "SPONSOR_NAME3"].replace(['JOYLAND REST'], "JOYLAND RESTAURANT")
data.loc[:, "SPONSOR_NAME3"] = data.loc[:, "SPONSOR_NAME3"].replace(['SUN KWONG ON'], "SUN KWONG ON CO")
data.loc[:, "SPONSOR_NAME3"] = data.loc[:, "SPONSOR_NAME3"].replace(['WING YING LUNG'], "WING YING LUNG CO")

# %%
data["SPONSOR_NAME2"].value_counts()
# Out:
# COLUMBIA UNIVERSITY          12
# WING ON WO CO                 6
# TUCK HIGH CO                  4
# NEW YORK UNIVERSITY           4
# TAI LUNG CO                   3
# YING CHONG CO                 3
# SHANGHAI RESTAURANT           3
# SAM KEE CO                    3
# SUN KWONG ON CO               3
# QUONG MEE YUEN CO             2
# WING WO CHONG CO              2
# WAH SANG TAI CO               2
# YOENG'S RESTAURANT            2
# CHOY CHONG WO CO              2
# CORNELL UNIVERSITY            2
# WAH CHONG LUNG CO             2
# SUN YUEN HING CO              2
# KWONG TAI CHONG CO            2
# SYRACUSE UNIVERSITY           2
# ORIENTAL RESTAURANT           2
# SUN QUONG ON CO               2
# CANTON RESTAURANT             2
# SAM WOH CO                    2
# KWONG YUEN SHING CO           2
# YALE UNIVERSITY               2
# CHANG CHAW BROS               2
# WING HING LUNG CO             2
# KING WAH LO RESTAURANT        2
# YEE LUNG CO                   1
# ...

# %%
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['COLUMBIA', 'COLUMBIA UNI', 'COLUMBIA U.'], "COLUMBIA UNIVERSITY")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['WING ON WO', 'WING ON WO & CO'], "WING ON WO CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['WING WO CHONG', 'WING WO CHONG & CO'], "WING WO CHONG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['QUONG MEE YUEN', 'QUONG MEE YUEN & CO'], "QUONG MEE YUEN CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['YALE'], "YALE UNIVERSITY")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CHOY CHONG WO'], "CHOY CHONG WO CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SUN YUEN HING'], "SUN YUEN HING CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CORNELL UNIV'], "CORNELL UNIVERSITY")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['TAI LUNG'], "TAI LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SUN CHONG LUNG'], "SUN CHONG LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['ORIENTAL RESTANT'], "ORIENTAL RESTAURANT")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SUN MAY LEE CO.'], "SUN MAY LEE CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['U. OF MINNESOTA'], "UNIVERSITY OF MINNESOTA")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['WING FAT HING KEE'], "WING FAT HING KEE CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['KWONG TAI CHONG'], "KWONG TAI CHONG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['WING HING LUNG'], "WING HING LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['TUCK HIGH CO.'], "TUCK HIGH CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['KWONG YUEN SHING'], "KWONG YUEN SHING CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['WING WOH HING'], "WING WOH HING CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['QUONG ON SHING'], "QUONG ON SHING CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['KWONG MOW YUEN'], "KWONG MOW YUEN CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SYRACUSE UNIV'], "SYRACUSE UNIVERSITY")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['VICEROY REST.'], "VICEROY RESTAURANT")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['FOOK HING LUNG & CO'], "FOOK HING LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['PARADISE REST.'], "PARADISE RESTAURANT")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['JONG YOUNG, REST.'], "JONG YOUNG RESTAURANT")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['ORIENT REST.'], "ORIENT RESTAURANT")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace([' UNIV OF NEW YORK', 'NEW YORK U.', 'N.Y. UNIVERSITY'], "NEW YORK UNIVERSITY")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['YICK LOCK HEW REST'], "YICK LOCK HEW RESTAURANT")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['WING FAT HING KEE'], "WING FAT HING KEE CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['LAU H. QUONG'], "LAU H. QUONG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['QUONG SUN CHONG'], "QUONG SUN CHONG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['N.Y.AIRBRAKE CO.'], "N.Y.AIRBRAKE CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CHUCH MON ON CO.'], "CHUCH MON ON CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['HIM SANG YUEN CO.'], "HIM SANG YUEN CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['WILSON & CO'], "WILSON CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['QUONG ON LUNG'], "QUONG ON LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['U.OF ILLINOIS'], "UNIVERSITY OF ILLINOIS")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['LEHIGH'], "LEHIGH UNIVERSITY")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SUN QUONG ON'], "SUN QUONG ON CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['FONG KEE CO.'], "FONG KEE CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['QUONG KING LUNG'], "QUONG KING LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['QUONG TAI CHONG'], "QUONG TAI CHONG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['YET WAH REST.'], "YET WAH RESTAURANT")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['QUONG ON LUN'], "QUONG ON LUN CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SAM WOH CO.'], "SAM WOH CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SUN KWONG LUNG'], "SUN KWONG LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SUN WAH YUEN'], "SUN WAH YUEN CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CHAN CHOW BROTHERS.'], "CHAN CHOW BROTHERS")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['KO GEE JON CO.'], "KO GEE JON CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['TUCK CHEONG CO.'], "TUCK CHEONG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['KWONG HING LUNG'], "KWONG HING LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['WING ON WAH'], "WING ON WAH CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['KUNG WO CO.'], "KUNG WO CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['PACIFIC REST.'], "PACIFIC RESTAURANT")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['QUONG YEE HING'], "QUONG YEE HING CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SUN KWONG ON'], "SUN KWONG ON CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['HARVARD'], "HARVARD UNIVERSITY")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CHOI GONG HIE CO.'], "CHOI GONG HIE CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CHINA VIEW REST.'], "CHINA VIEW RESTAURANT")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SUN KWONG LUN'], "SUN KWONG LUN CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CORNELL'], "CORNELL UNIVERSITY")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CHING CHONG'], "CHING CHONG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['MIGUEL ATAK & CO'], "MIGUEL ATAK CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['KWAN LEE & CO'], "KWAN LEE CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['YEE HING LUNG'], "YEE HING LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CHANG CHAW BROS.'], "CHANG CHAW BROS")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['HIP TAI SING & CO'], "HIP TAI SING CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['YEE CHONG STORE'], "YEE CHONG CO")
# data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['HIP CHONG LUNG & HING KEE'], "HIP CHONG LUNG HING KEE")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['MT.HERMON'], "MT. HERMON")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['SUN KEEY CO.'], "SUN KEEY CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['CHONG LUNG & CO'], "CHONG LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['YEE LUNG CO.'], "YEE LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['QUONG HING LUNG'], "QUONG HING LUNG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['LIN FONG & CO.'], "LIN FONG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['WING WOH CHONG'], "WING WOH CHONG CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['TUCK HIGH'], "TUCK HIGH CO")
data.loc[:, "SPONSOR_NAME2"] = data.loc[:, "SPONSOR_NAME2"].replace(['TSUE CHONG WAH'], "TSUE CHONG WAH STORE")

# %%
data["SPONSOR_NAME1"].value_counts()
# Out:
# COLUMBIA UNIVERSITY                      58
# SUN KWONG ON CO                          42
# WING ON WO CO                            36
# QUONG YEE WO CO                          35
# WING WO CHONG CO                         35
# SOY KEE CO                               33
# QUONG YUEN SHING CO                      27
# KWONG TAI CHONG CO                       25
# CORNELL UNIVERSITY                       23
# TAI LUNG CO                              23
# CANTON RESTAURANT                        21
# SANG CHONG CO                            21
# YING CHONG CO                            20
# ORIENTAL RESTAURANT                      19
# QUONG WO CHONG CO                        19
# TUCK HIGH CO                             19
# YEE HING CO                              19
# KUAN TANG LUNG CO                        18
# HOP LUNG CO                              18
# QUONG WING SHING CO                      16
# KWONG YUEN SHING CO                      15
# ...

# %%
# get rid of all the &s

for i in range(len(data["SPONSOR_NAME1"])):
    line = data["SPONSOR_NAME1"][i]
    if type(line) != float:
        if '& CO' in line:
            data["SPONSOR_NAME1"][i] = line.replace('& CO', 'CO')
        elif 'CO.' in line:
            data["SPONSOR_NAME1"][i] = line.replace('CO.', 'CO')
        elif '&CO' in line:
            data["SPONSOR_NAME1"][i] = line.replace('&CO', 'CO')
        elif '&CO.' in line:
            data["SPONSOR_NAME1"][i] = line.replace('&CO.', 'CO')
        elif '& CO.' in line:
            data["SPONSOR_NAME1"][i] = line.replace('& CO.', 'CO')
        elif '& CO .' in line:
            data["SPONSOR_NAME1"][i] = line.replace('& CO .', 'CO')
        elif 'CO.' in line:
            data["SPONSOR_NAME1"][i] = line.replace('CO.', 'CO')
        if 'CORPORATION' not in line:
            if 'CORP.' in line:
                data["SPONSOR_NAME1"][i] = line.replace('CORP.', 'CORPORATION')
            elif 'CORP' in line:
                data["SPONSOR_NAME1"][i] = line.replace('CORP', 'CORPORATION')
        if 'RESTAURANT' not in line:
            if 'REST' in line:
                data["SPONSOR_NAME1"][i] = line.replace('REST', 'RESTAURANT')
            elif 'REST.' in line:
                data["SPONSOR_NAME1"][i] = line.replace('REST.', 'RESTAURANT')
        if 'RESTAURANT.' in line:
            data["SPONSOR_NAME1"][i] = line.replace('RESTAURANT.', 'RESTAURANT')
        if 'RESTAURANTUARANT' in line:
            data["SPONSOR_NAME1"][i] = line.replace('RESTAURANTUARANT', 'RESTAURANT')
        elif 'RESTAURANTAURNAT' in line:
            data["SPONSOR_NAME1"][i] = line.replace('RESTAURANTAURNAT', 'RESTAURANT')
        elif 'RESTAURANTAURNT' in line:
            data["SPONSOR_NAME1"][i] = line.replace('RESTAURANTAURNT', 'RESTAURANT')
        elif 'RESTAURANTA.' in line:
            data["SPONSOR_NAME1"][i] = line.replace('RESTAURANTA.', 'RESTAURANT')
        if 'CORPORATIONORATION' in line:
            data["SPONSOR_NAME1"][i] = line.replace('CORPORATIONORATION', 'CORPORATION')

# %%
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN KWONG ON'], "SUN KWONG ON CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG YUEN SHING'], "QUONG YUEN SHING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG YEE WO'], "QUONG YEE WO CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING WO CHONG'], "WING WO CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING ON WO'], "WING ON WO CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG WO CHONG'], "QUONG WO CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG TAI CHONG'], "KWONG TAI CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CORNELL UNIV.', 'CORNELL', 'CORNELL UNIV'], "CORNELL UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['COLUMBIA UNIV.', 'COLUMBIA UNIV', 'COLUMBIA', 'COLOMBIA'], "COLUMBIA UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG YUEN SHING'], "KWONG YUEN SHING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HIP CHUNG WING'], "HIP CHUNG WING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG HING LUNG'], "QUONG HING LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN YUEN HING'], "SUN YUEN HING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG YEE HING'], "QUONG YEE HING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SOY KEE CO.'], "SOY KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING WAH HING'], "WING WAH HING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG MEE YUEN'], "QUONG MEE YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG TAI CHONG'], "QUONG TAI CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN MEE YUEN'], "SUN MEE YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG WAH CHONG'], "QUONG WAH CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN LEE CHONG'], "SUN LEE CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HARVARD'], "HARVARD UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['MAN FAT YUEN'], "MAN FAT YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['LIN FONG CO.'], "LIN FONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG ON SHING'], "QUONG ON SHING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN QUONG LUNG'], "SUN QUONG LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TAI LUNG CO.'], "TAI LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG SUN CHONG'], "KWONG SUN CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG TUCK WING'], "QUONG TUCK WING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG HING CHONG'], "QUONG HING CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG KING LONG & CO'], "QUONG KING LONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG KING LUNG'], "QUONG KING LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CHING CHONG CO.'], "CHING CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG SANG WO'], "QUONG SANG WO CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING HING LUNG'], "WING HING LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG CHIN CHONG & CO'], "KWONG CHIN CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING YEE YUEN', 'WING YEE YUEN & COMPANY'], "WING YEE YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['UNIV. OF PENN', 'UNIVERSITY OF PENN', 'U. OF PENN'], "UNIVERSITY OF PENNSYLVANIA")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TSUE CHONG WO YICK KEE CO'], "TSUE CHONG WOH YICK KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SOY KEE'], "SOY KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['LAU H QUONG CO', 'LAU H QUONG', 'LAU H. QUONG'], "LAU H. QUONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG ON LUNG'], "QUONG ON LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HIP CHONG LUNG'], "HIP CHONG LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING WOH CHONG'], "WING WOH CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING ON WAH'], "WING ON WAH CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING WO CHUNG'], "WING WO CHUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING YING LUNG'], "WING YING LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING LUNG KEE'], "WING LUNG KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG WAH LUNG'], "QUONG WAH LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING FAT HING KEE'], "WING FAT HING KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HONG ON TAI'], "HONG ON TAI CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TSUE CHONG WAH'], "TSUE CHONG WAH STORE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['YANG TSE CORP.'], "YANG TSE CORPORATION")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG YEE WO', 'KWONG YEE WOH', 'KWONG YEE WOH CO'], "KWONG YEE WO CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SAM SING'], "SAM SING STORE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG YICK YUEN'], "QUONG YICK YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['R.P.I.', 'RPI'], "R.P.I.")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['MAN GAR CHUN'], "MAN GAR CHUN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TANGERINE GARDENS REST.'], "TANGERINE GARDENS RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['MANDARIN REST.'], "MANDARIN RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HOP WAH LUNG'], "HOP WAH LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG YICK YUEN'], "KWONG YICK YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING TONG FOOK'], "WING TONG FOOK CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN WAH YUEN'], "SUN WAH YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HONG FAR CHUEN REST.'], "HONG FAR CHUEN RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CHINA REPUBLIC REST.'], "CHINA REPUBLIC RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CHOP STICKS REST'], "CHOP STICKS RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CHINESE REPUBLIC REST.'], "CHINESE REPUBLIC RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HONG FAR LOW'], "HONG FAR LOW RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN CHUNG LUNG & SO'], "SUN CHUNG LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG TAI CHUNG'], "KWONG TAI CHUNG STORE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TSUE CHONG WO YICK KEE'], "TSUE CHONG WO YICK KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CHINESE COMMERCIAL CO LTD.'], "CHINESE COMMERCIAL CO LTD")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG WAH LUN'], "QUONG WAH LUN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['MICHIGAN', 'THE UNIV OF MICHIGAN', 'UNIV.OF MICHIGAN'], "UNIVERSITY OF MICHIGAN")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['MAN YICK LUNG'], "MAN YICK LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG, WING, CHONG CO'], "QUONG WING CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TUCK WING LUNG'], "TUCK WING LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KUNG WO ST'], "KUNG WO STORE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SYRACUSE UNIV.'], "SYRACUSE UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUEY PANG\'S REST'], "SUEY PANG'S RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG TAI CHUNG'], "QUONG TAI CHUNG'S STORE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KUNG YICK SO'], "KUNG YICK CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG HUNG YUEN'], "KWONG HUNG YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PEKIN REST.'], "PEKIN RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HOP LUNG'], "HOP LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG LUNG YUEN'], "QUONG LUNG YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING HONG YUEN'], "WING HONG YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['RIDGEWOOD GARDEN CAFE]'], "RIDGEWOOD GARDEN CAFE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PHILA. TEXTILE SCHOOL'], "PHILADELPHIA TEXTILE SCHOOL")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CHIN LEE'], "CHIN LEE RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['YIN HEE REST.'], "YIN HEE RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CHINA- AMERICA IMPORT CO'], "CHINA-AMERICA IMPORT CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUEY SANG LUNG'], "SUEY SANG LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING TAI LUNG'], "WING TAI LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING WAH CHONG'], "WING WAH CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SAM LEE'], "SAM LEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SING KEE'], "SING KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['20 CHINESE SEAMEN - (SEE COMMENTS)'], "20 CHINESE SEAMEN")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PALAI D\'OR RESTAURANT', 'PALIS DOR RESTAURANT', 'PALAIS DO\'R RESTAURANT', 'PALAIS DE\'OR RESTAURANT'], "PALAIS D'OR RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['UNIVERSITY OF NEW YORK'], "NEW YORK UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PT RICHMOND TEA GARDEN REST.'], "POINT RICHMOND TEA GARDEN RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WP FULLER'], "W. P. FULLER CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SS BONES CASTLE\'S SEAMEN - (SEE COMMENTS)'], "SS BONES CASTLE\'S SEAMEN")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG MEE YUEN'], "KWONG MEE YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN TAI JAN'], "SUN TAI JAN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TUCK HIGH'], "TUCK HIGH CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WESLEYAN UNIV.'], "WESLEYAN UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['YEE YICK'], "YEE YICK CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG WO LUNG'], "QUONG WO LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG YUEN LUNG', 'QUONG YUEN LUNG STORE'], "QUONG YUEN LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG WING SHING'], "QUONG WING SHING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG N  RESTAURANT'], "QUONG N RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['NIGHTLESS BROOKLYN REST'], "NIGHTLESS BROOKLYN RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['EAGLE REST'], "EAGLE RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TO STUDY AT M.I.T.'], "MIT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['FULTON ROYALE REST'], "FULTON ROYALE RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PHILLIPS ACAD'], "PHILLIPS ACADEMY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['UNIV. OF CHICAGO'], "UNIVERSITY OF CHICAGO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PHEASANT REST.'], "PHEASANT RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['YOUNG\'S REST.'], "YOUNG\'S RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG HING LUNG CHONG KEE'], "QUONG HING LUNG CHONG KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['FONG KEE'], "FONG KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HIP TUCK, LUNG CO'], "HIP TUCK LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['NEW BEDFORD'], "NEW BEDFORD TEXTILE SCHOOL")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TOM KIM REST.'], "TOM KIM RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['STAR REST.'], "STAR RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['LONG SANG TI', 'LONG SANG TI CURIO'], "LONG SANG TI CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HONG FAR LOW REST'], "HONG FAR LOW RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HING KEE'], "HING KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SAM WAH'], "SAM WAH CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['BIBLE TEACHER\'S TRAINING SCH'], "BIBLE TEACHER\'S TRAINING SCHOOL")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PRINCETON U.', 'PRINCETON'], "PRINCETON UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WO ON'], "WO ON CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['FOW, YUEN CO'], "FOW YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN WO YUEN'], "SUN WO YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN QUONG JAN'], "SUN QUONG JAN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING CHONG LONG'], "WING CHONG LONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['THE VALLEY STREAM RESTA.'], "THE VALLEY STREAM RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WAH CHUNG LUNG'], "WAH CHUNG LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KUAN TANG LUNG'], "KUAN TANG LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG HING LUNG'], "KWONG HING LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['MT HERMAN SCHOOL COLOMBIA'], "MOUNT HERMON SCHOOL COLOMBIA")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG CHONG'], "KWONG CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HIP TUCK LUNG'], "HIP TUCK LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['YALE'], "YALE UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CELESTIAL REST.'], "CELESTIAL RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['FAR EAST REST.'], "FAR EAST RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG MOW YUEN'], "QUONG MOW YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['MEE YUEN LUNG'], "MEE YUEN LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KING HONG LOW'], "KING HONG LOW RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['FRANK LEE'], "FRANK LEE LAUNDRY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG WOH TAI'], "KWONG WOH TAI CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG YUEN SING'], "QUONG YUEN SING CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SUN DE LUXE REST.'], "SUN DE LUXE RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['U.OF MINNESOTA'], "UNIVERSITY OF MINNESOTA")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG SANG TAI'], "QUONG SANG TAI CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WAH LEE'], "WAH LEE LAUNDRY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SANG CHONG'], "SANG CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['ORIENTAL REST'], "ORIENTAL RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CHAN CHOW & BROS', 'CHAN CHOW BROTHERS.'], "CHAN CHOW BROTHERS")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['U.S.POST OFFICE'], "U.S. POST OFFICE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HIP CHONG LUNG HING KEE'], "HIP CHONG LUNG HING KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUONG LEE KEE'], "QUONG LEE KEE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['FOOK CHONG'], "FOOK CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['YAT GAW MIN'], "YAT GAW MIN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['MUN YICK LUNG'], "MUN YICK LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUAN TAI LOY'], "QUAN TAI LOY CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['COOPER UNION COLUMBIA UNIV.'], "COOPER UNION COLUMBIA UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['YEE WAH LUNG'], "YEE WAH LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PS-15'], "PS15")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['QUAN YICK LUNG'], "QUAN YICK LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WING YEE YUEN', 'WING YEE YUEN & COMPANY'], "WING YEE YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HING LUM CHONG'], "HING LUM CHONG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['COLORADO COLL.'], "COLORADO COLLEGE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG LEE YUEN'], "KWONG LEE YUEN CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CHOY CHONG HIE'], "CHOY CHONG HIE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['GEORGETOWN UNIV.'], "GEORGETOWN UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WAH KUE'], "WAH KUE CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['KWONG WAH TAI'], "KWONG WAH TAI CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['YEE WOH'], "YEE WOH CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['COLUMBIA U.'], "COLUMBIA UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['INDIANA UNIV.'], "INDIANA UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['YEE CHONG LUNG'], "YEE CHONG LUNG CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['ASUBRY COLLEGE'], "ASBURY COLLEGE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PORT AURTHUR RESTAURANT'], "PORT ARTHUR RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['ST MARYS COLLEGE'], "ST MARY'S COLLEGE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PAGAENT\'S RESTAURANT'], "PAGEANT'S RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['COYNE TRADE&ENGINEERING SCHOOL'], "COYNE TRADE & ENGINEERING SCHOOL")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['ORPHEUN CIRCUIT'], "ORPHEUM CIRCUIT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SPRINGFILED YMCA'], "SPRINGFIELD YMCA")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['INDUSTCOMMER BANK OF HONGKON'], "INDUSTCOMMER BANK OF HONG KONG")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['THISLTE TAVERN'], "THISTLE TAVERN")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['STEVENS INST. OF TECHNOLOGYY'], "STEVENS INSTITUTE OF TECHNOLOGY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['PAGAENT TEA GARDEN'], "PAGEANT TEA GARDEN")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['BRITISH AMER TABACOO CO'], "BRITISH AMER TOBACCO CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TRINIDAD AUTO&CYCLE SUPPLY CO'], "TRINIDAD AUTO & CYCLE SUPPLY CO")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SHANGHAI BOADING HOUSE'], "SHANGHAI BOARDING HOUSE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CANTON HOISERY MILL'], "CANTON HOSIERY MILL")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HOP SING LAUDNRY'], "HOP SING LAUNDRY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['TANGERINGE TEA GARDEN'], "TANGERINE TEA GARDEN")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['BIBLICAL SEMIANRY'], "BIBLICAL SEMINARY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['SCARRIT COLLEGE'], "SCARRITT COLLEGE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['CATHAM RESTAURANT'], "CHATHAM RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['EXCELSOIR GENERAL STORE'], "EXCELSIOR GENERAL STORE")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['WISTARIS RESTAURANT'], "WISTARIA RESTAURANT")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['HARVARD COLLAGE'], "HARVARD UNIVERSITY")
data.loc[:, "SPONSOR_NAME1"] = data.loc[:, "SPONSOR_NAME1"].replace(['RENSAELAER POLY TECH'], "RENSSELAER POLY TECH")

# %% [markdown]
# # Output

# %%
# SPONSOR = data.loc[:, 'SPONSOR']
# header = ['SPONSOR']
# SPONSOR.to_csv('./cleaned_data/SPONSOR.csv', columns = header, index=False)

# %%
# output from list
# df = pd.DataFrame(data={"SPONSOR_NAME": sponsor_name, "geo_marker": geo_markers})
# df.to_csv("./SPONSOR_SEP.csv", sep=',',index=False)

# %%
df = pd.DataFrame(data={"SPONSOR_NAME1": data.loc[:, "SPONSOR_NAME1"], 
                        "SPONSOR_NAME2": data.loc[:, "SPONSOR_NAME2"], 
                        "SPONSOR_NAME3": data.loc[:, "SPONSOR_NAME3"]})
df.to_csv("./SPONSOR_SEP_cleaned.csv", sep=',',index=False)
