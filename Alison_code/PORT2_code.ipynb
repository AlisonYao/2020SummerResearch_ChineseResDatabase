# %%
# %cd drive/My\ Drive/HRL/Data\ Cleaning
# Out:
# /content/drive/My Drive/HRL/Data Cleaning

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('NY_data.xlsx')
data.head()
# Out:
#   DONE Y/N NO FORM 431        DATE  Unnamed: 3  ...  STREET3  CITY3  STATE3  MEMO2
# 0      NaN         NaN         NaN         NaN  ...      NaN    NaN     NaN    NaN
# 1      NaN           X  2020.03.18         1.0  ...      NaN    NaN     NaN    NaN
# 2      NaN         NaN         NaN         NaN  ...      NaN    NaN     NaN    NaN
# 3      NaN         NaN         NaN         NaN  ...      NaN    NaN     NaN    NaN
# 4      NaN         NaN         NaN         NaN  ...      NaN    NaN     NaN    NaN
#
# [5 rows x 52 columns]

# %%
data.info()
# index 32 is port2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18563 entries, 0 to 18562
# Data columns (total 52 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DONE Y/N     233 non-null    object
#  1   NO FORM 431  556 non-null    object
#  2   DATE         789 non-null    object
#  3   Unnamed: 3   781 non-null    float64
#  4   Screened     18562 non-null  float64
#  5   BOX          18562 non-null  float64
#  6   CASENO1      18561 non-null  float64
#  7   CASENO2      18559 non-null  float64
#  8   NAME1        18552 non-null  object
#  9   NAME2        18545 non-null  object
#  10  NAME3        10155 non-null  object
#  11  ALIAS1       8545 non-null   object
#  12  ALIAS2       8528 non-null   object
#  13  ALIAS3       6574 non-null   object
#  14  CHINESE1     10960 non-null  object
#  15  CHINESE2     10962 non-null  object
#  16  CHINESE3     6591 non-null   float64
#  17  CHINESE4     68 non-null     float64
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(["NEW YORK,NY", 'NEW YORK', 'NEW YORK CITY', 'NEW YOR, NY', 'NEW YOKR,NY', 'NEW YROK, N', 'NEW YROK, NY'],"NEW YORK, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['MALONE,NY', 'MALONE', 'MALONE NY', 'MOLONE, NY', 'MLAONE,NY'], "MALONE, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['SEATTLE,WA', 'SEATTLE', 'SEATTLE WA', 'SEATTKE', 'SEATTLE, NY', 'SEATTTLE, WA', 'SEATTLE  WA', 'SEATTLE]', 'SEATTLE, W', 'SEATTLE. WA', 'SEATTLE,NY', 'SEATTLE ,WA', 'SEATTLE WA.', 'SETATTLE', 'SEATTKE,WA'], "SEATTLE, WA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['BOSTON,MA', 'BOSTON'], "BOSTON, MA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['VANCOUVER', 'VANCOUVER,B.C.', 'VANVCOUVER', 'VANCOUVER,BC'], "VANCOUVER, B.C.")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['SAN FRANCISCO', 'SAN FRANCSICO', 'SAB FRANCISCO'], "SAN FRANCISCO, CA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['RICHFORD,VT', 'RICHFROD,VT', 'RICHFORD VT'], "RICHFORD, VT")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['ST ALBANS,VT', 'ST ALBANS, VT', 'ST ALBAN\'S', 'ST ALBANY,VT'], "ST. ALBANS, VT")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['RICHFORD,VT', 'RICHFROD,VT', 'RICHFORD VT'], "RICHFORD, VT")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['NY VIA TRINIDAD', 'NY VIA HAVANA', 'NY VIA MEXICO', 'NY VIA CUBA', 'NY VIA CANADA', 'NY VIA CUBA'], "NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['PLATTSBURGH,NY', 'PLATTSBURG,NY', 'PLATTSBURG, NY'], "PLATTSBURGH, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['MONTREAL', 'MONTREAL,CANADA'], "MONTREAL, CANADA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['BURLINGTON,VT'], "BURLINGTON, VT")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['VERMONT'], "VT")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['ROUSES POINT,NY', 'ROUSE PORT, NY', 'REUSES PONIT,NY'], "ROUSES POINT, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['BUFFALO,NY', 'BUFFALO', 'BUFFAOL, NY'], "BUFFALO, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['PHILADELPHIA', 'PHILADELPHIA,PA'], "PHILADELPHIA, PA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['BROOKLYN,NY'], "BROOKLYN, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['BALTIMORE,MD', 'BALTIMORE'], "BALTIMORE, MD")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['LOS ANGELES'], "LOS ANGELES, CA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['HONOLULU', 'HONOLULU,HI'], "HONOLULU, HI")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['BROOKLYN,NY'], "BROOKLYN, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['EAST BOSTON MA'], "EAST BOSTON, MA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['VICTORIA,BC', 'VICTORIA'], "VICTORIA, B.C.")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['PT TOWNSEND,WA', 'TOWNSEND,WA', 'PT TOWNSEND, WA'], "PORT TOWNSEND, WA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['PORTAL,ND'], "PORTAL, ND")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['PT HENRY,NY', 'PORT HENRY,NY', 'POINT HENRY,NY'], "PORT HENRY, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['DETROIT', 'DEROIT, MI'], "DETROIT, MI")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['NEWPORT,VT'], "NEWPORT, VT")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['NIAGARAFALLS,NY', 'NIAGARA FALLS'], "NIAGARA FALLS, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['TACOMA,WA'], "TACOMA, WA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['MOUNT VERNON,NY'], "MOUNT VERNON, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['LAREDO'], "LAREDO, TX")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['LEWISTON, NY(?)'], "LEWISTON, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['OGDENSBURG,NY'], "OGDENSBURG, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['PORTLAND,OR'], "PORTLAND, OR")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['EL PASO,TX'], "EL PASO, TX")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['SUMAS,WA'], "SUMAS, WA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['HOBOKEN,NJ'], "HOBOKEN, NJ")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['SAULTE STE MARI', 'SAULT STE MARIE', 'SAULTE STE. MARI, CANADA'], "SAULT STE. MARI, CANADA")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['MINNEAPOLIS,MN'], "MINNEAPOLIS, MN")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['POUGHKEEPSIE,NY'], "POUGHKEEPSIE, NY")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['DAYTONA, FL'], "DAYTONA BEACH, FL")
data.loc[:,"PORT2"] = data.loc[:,"PORT2"].replace(['22', 'K'], "")

# %%
data["PORT2"].value_counts()
# Out:
# MALONE,NY          1953
# SEATTLE, WA        1191
# SAN FRANCISCO       635
# NEW YORK, NY        524
# SEATTLE,WA          506
# SEATTLE             480
# MALONE, NY          389
# NEW YORK            322
# NEW YORK,NY         213
# VANCOUVER           111
# BOSTON,MA            62
# BOSTON, MA           46
# BOSTON               43
# RICHFORD,VT          30
# MONTREAL             29
# VANCOUVER,BC         20
# PLATTSBURGH,NY       14
# BURLINGTON,VT        11
# ST ALBANS,VT         11
# NY VIA TRINIDAD      11
# BUFFALO, NY          11
# ST ALBANS, VT        10
# RICHFORD, VT          9
# MALONE                9
# SEATTLE WA            9
# ROUSES POINT,NY       9
# PHILADELPHIA          8
# NEW YORK CITY         7
# EAST BOSTON, MA       7
# LOS ANGELES, CA       6
# SAN PEDRO, CA         6
# BUFFALO,NY            6
# ST. ALBANS, VT        5
# PORT HENRY, NY        5
# HONOLULU, HI          5
# MONTREAL,CANADA       4
# PORTAL,ND             4
# PT TOWNSEND,WA        4
# ...

# %%
lst = data.loc[:,"PORT2"]
CITY = []
STATE = []
for i in lst:
    if pd.notnull(i):
        temp = i.split(",")
        if len(temp) != 1 and len(temp) != 2:
            print(temp)
        if len(temp) == 1:
            CITY.append(0)
            STATE.append(temp[0].strip())
        else:
            CITY.append(temp[0].strip())
            STATE.append(temp[1].strip())
    else:
        CITY.append(i)
        STATE.append(i)

# %%
header = ['PORT2']
PORT2 = data.loc[:,"PORT2"]
PORT2.to_csv('./cleaned_data/PORT2.csv', columns = header, index=False)
