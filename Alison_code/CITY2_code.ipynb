# %%
# %cd drive/My\ Drive/HRL/Data\ Cleaning
import pandas as pd
import numpy as np
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/HRL/Data Cleaning'
# /content/drive/My Drive/HRL/Data Cleaning

# %%
data = pd.read_excel('NY_data.xlsx')
data.head()
# Out:
#   DONE Y/N NO FORM 431        DATE  Unnamed: 3  Screened  BOX  CASENO1  \
# 0      NaN         NaN         NaN         NaN       0.0  1.0      5.0
# 1      NaN           X  2020.03.18         1.0       0.0  1.0      5.0
# 2      NaN         NaN         NaN         NaN       0.0  1.0      5.0
# 3      NaN         NaN         NaN         NaN       0.0  1.0      5.0
# 4      NaN         NaN         NaN         NaN       0.0  1.0      5.0
#
#    CASENO2    NAME1 NAME2 NAME3 ALIAS1 ALIAS2 ALIAS3 CHINESE1 CHINESE2  \
# 0      3.0     CHIN   GOK    PO   CHIN   KUNG   PACK      NaN      NaN
# 1      4.0      HOM  CHEE   NaN   DONG     AH   CHEE      NaN      NaN
# 2      9.0  WILLIAM     K  WONG   WONG   KING   SING      NaN      NaN
# 3     10.0      LEE   DEN   NaN    NaN    NaN    NaN      NaN      NaN
# 4     19.0      YEE  HING   NaN     YU    YUK    YIN      NaN      NaN
#
#    CHINESE3  CHINESE4 SEX           PORT     BIRTHPLACE HOMETOWN OCUPATION1  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data["CITY2"].value_counts()
# Out:
# NEW YORK               1357
# BROOKLYN                162
# NEWARK                   92
# PHILADELPHIA             76
# BOSTON                   48
# SAN FRANCISCO            48
# BRONX                    34
# WASHINGTON               23
# BALTIMORE                22
# BUFFALO                  20
# PATERSON                 15
# NEW HAVEN                14
# ALBANY                   13
# JERSEY CITY              12
# LONG ISLAND              11
# CLEVELAND                10
# CHICAGO                   9
# NEW YORK, NY              7
# JAMAICA                   7
# BRIDGEPORT                7
# STATEN ISLAND             6
# PORTLAND                  6
# OAKLAND                   6
# WASHINGTON D.C.           5
# YONKERS                   5
# TROY                      5
# ELIZABETH                 4
# NEW ROCHELLE              4
# NORFOLK                   4
# PROVIDENCE                4
# DANBURY                   4
# BERKELEY                  4
# NEW LONDON                4
# ...

# %%
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['NEW YORK, NY', 'NEW YOR', 'NEW YORK\'', 'NY, NY', 'NER YORK'], "NEW YORK")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['PHILADELPHIA, PA'], "PHILADELPHIA")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['BOSTON, MA'], "BOSTON")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['MALONE, NY'], "MALONE")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['FLINT, MICH'], "FLINT")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['ROCHESTER,'], "ROCHESTER")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['E. NEW YORK, NY'], "E. NEW YORK")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['CHICOPEE FALLS,'], "CHICOPEE FALLS")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['SAN FRANCISCO, CA'], "SAN FRANCISCO")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['BOONTON, NJ'], "BOONTON")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['NEWARK,'], "NEWARK")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['BROOKLYN,'], "BROOKLYN")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['WASHINGTON D.C.'], "WASHINGTON")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['LONG ISLAND CITY'], "LONG ISLAND")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['BUFFALO,'], "BUFFALO")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['JERSEY CITY, NJ'], "JERSEY CITY")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['CAMDEN,'], "CAMDEN")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['BRIDGEPORT, CONN'], "BRIDGEPORT")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['JAMAICA,LONG ISLAND'], "JAMAICA, LONG ISLAND")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['CONEY ISLAND,'], "CONEY ISLAND")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['PHILADEPHIA', 'PHILADELPAIA', 'PHILADLEPHIA'], "PHILADELPHIA")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['MONTOGMERY'], "MONTGOMERY")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['LOUISVILL'], "LOUISVILLE")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['WORCHESTER'], "WORCESTER")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['SAN FRANCICSO'], "SAN FRANCISCO")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['PAHWAY'], "RAHWAY")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['SARANCE LAKE'], "SARANAC LAKE")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['AMSTERDAN'], "AMSTERDAM")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['WILKINGSBURG'], "WILKINSBURG")
data.loc[:, "CITY2"] = data.loc[:, "CITY2"].replace(['MOUTAIN HOME'], "MOUNTAIN HOME")

# %%
SEX = data.loc[:, 'CITY2']
header = ['CITY2']
SEX.to_csv('./cleaned_data/CITY2.csv', columns = header, index=False)
